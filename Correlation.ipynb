# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
ncen = 30

for i in range(ncen):
    xc = np.random.rand(2)
    x = np.random.randn(2,10)*0.1
    x[0] += xc[0]
    x[1] += xc[1]
    plt.scatter(x[0],x[1])

y = np.random.rand(2,1)
